# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv("ecommerce_sales_practice.csv")

# %%
data
# Out:
#     order_id     product     category       city  quantity  unit_price  \
# 0       1001      Laptop    Computers    Chennai         5         500
# 1       1002       Mouse  Electronics    Chennai         4         800
# 2       1003  Smartphone  Accessories       Pune         5        2500
# 3       1004      Tablet    Computers    Chennai         3        2500
# 4       1005       Mouse  Accessories     Mumbai         2         500
# 5       1006  Smartphone  Electronics       Pune         3        2500
# 6       1007      Laptop  Accessories     Mumbai         4        5000
# 7       1008      Tablet  Accessories  Hyderabad         3        2500
# 8       1009     Monitor    Computers  Hyderabad         2         800
# 9       1010     Monitor  Accessories      Delhi         5        8000
# 10      1011      Laptop  Electronics  Hyderabad         3         800
# 11      1012  Headphones    Computers      Delhi         5        8000
# ...

# %%
data.head()
# Out:
#    order_id     product     category     city  quantity  unit_price  \
# 0      1001      Laptop    Computers  Chennai         5         500
# 1      1002       Mouse  Electronics  Chennai         4         800
# 2      1003  Smartphone  Accessories     Pune         5        2500
# 3      1004      Tablet    Computers  Chennai         3        2500
# 4      1005       Mouse  Accessories   Mumbai         2         500
#
#    customer_rating payment_method  total_amount
# 0              2.8           Card          2500
# 1              3.2           Card          3200
# 2              4.5            UPI         12500
# 3              3.3           Cash          7500
# 4              4.9           Card          1000

# %%
data.tail()
# Out:
#     order_id     product     category       city  quantity  unit_price  \
# 45      1046  Smartwatch  Electronics  Bangalore         2        1200
# 46      1047      Tablet  Electronics       Pune         2       15000
# 47      1048     Monitor  Accessories  Hyderabad         3        8000
# 48      1049      Laptop  Electronics       Pune         3         800
# 49      1050  Headphones  Electronics  Hyderabad         4        5000
#
#     customer_rating payment_method  total_amount
# 45              2.9           Card          2400
# 46              3.5           Cash         30000
# 47              3.6            UPI         24000
# 48              4.0           Cash          2400
# 49              3.7           Cash         20000

# %%
data.describe()
# Out:
#          order_id   quantity    unit_price  customer_rating   total_amount
# count    50.00000  50.000000     50.000000        50.000000      50.000000
# mean   1025.50000   3.280000   8310.000000         3.762000   29458.000000
# std      14.57738   1.355864   9387.187316         0.746937   39511.739873
# min    1001.00000   1.000000    500.000000         2.500000     500.000000
# 25%    1013.25000   2.000000   1200.000000         3.200000    2500.000000
# 50%    1025.50000   3.000000   5000.000000         3.700000   12500.000000
# 75%    1037.75000   4.750000  13250.000000         4.375000   40000.000000
# max    1050.00000   5.000000  30000.000000         5.000000  150000.000000

# %%
data.isnull().sum()
# Out:
# order_id           0
# product            0
# category           0
# city               0
# quantity           0
# unit_price         0
# customer_rating    0
# payment_method     0
# total_amount       0
# dtype: int64

# %%
data.head()
# Out:
#    order_id     product     category     city  quantity  unit_price  \
# 0      1001      Laptop    Computers  Chennai         5         500
# 1      1002       Mouse  Electronics  Chennai         4         800
# 2      1003  Smartphone  Accessories     Pune         5        2500
# 3      1004      Tablet    Computers  Chennai         3        2500
# 4      1005       Mouse  Accessories   Mumbai         2         500
#
#    customer_rating payment_method  total_amount
# 0              2.8           Card          2500
# 1              3.2           Card          3200
# 2              4.5            UPI         12500
# 3              3.3           Cash          7500
# 4              4.9           Card          1000

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['order_id'],data['quantity'])

# %%
plt.bar(data['order_id'],data['quantity'])
plt.show()

# %%
plt.barh(data['order_id'],data['quantity'])
plt.show()

# %%
data.head()
# Out:
#    order_id     product     category     city  quantity  unit_price  \
# 0      1001      Laptop    Computers  Chennai         5         500
# 1      1002       Mouse  Electronics  Chennai         4         800
# 2      1003  Smartphone  Accessories     Pune         5        2500
# 3      1004      Tablet    Computers  Chennai         3        2500
# 4      1005       Mouse  Accessories   Mumbai         2         500
#
#    customer_rating payment_method  total_amount
# 0              2.8           Card          2500
# 1              3.2           Card          3200
# 2              4.5            UPI         12500
# 3              3.3           Cash          7500
# 4              4.9           Card          1000

# %%
city_count = data["city"].value_counts()

plt.pie(
    city_count,
    labels=city_count.index,
    autopct="%1.1f%%"
)

plt.title("order Distribution by City")

plt.show()
